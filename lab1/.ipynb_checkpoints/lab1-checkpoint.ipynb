# %% [markdown]
# # Laboratorium 1

# %% [markdown]
# ### Napisać program w języku Julia do obliczania iloczynu skalarnego wektorów (LinearAlgebra.dot) i mnożenia macierzy kwadratowej przez wektor z użyciem operatora *.

# %%
using DataFrames
using CSV
using Statistics
using LinearAlgebra
using Plots

# %% [markdown]
# ##### funkcja licząca iloczyn skalarny dwóch wygenerowanych losowo macierzy

# %%
function scalarProduct(size)
    matrix1 = rand(size)
    matrix2 = rand(size)
    @elapsed matrix1 ⋅ matrix2
end
# Out:
# scalarProduct (generic function with 1 method)

# %% [markdown]
# ##### funkcja mnozenia wygenerowanej kwadratowej macierzy przez wygenerowany wektor x

# %%
function multiplyMatrices(size)
    matrix = rand(size, size)
    vector = rand(size)
    @elapsed matrix .* vector
end
# Out:
# multiplyMatrices (generic function with 1 method)

# %% [markdown]
# ###  Uruchomić i zmierzyć czasy działania obydwu funkcji - każdej dla różnych rozmiarów wektorów. Dokonać 10 pomiarów dla każdego rozmiaru wektora.

# %% [markdown]
# ##### Pomiar dla funkcji liczącej iloczyn skalarny oraz dla funkcji mnożącej kwadratową macierz przez wektor

# %%
df = DataFrame(size=Int[], type=String[], time=Float64[])
output = "results.csv"
for i = 1:10, j = 1:10
    size = 10000*i
    push!(df, (size, "iloczyn_skalarny", scalarProduct(size)))
end
for i = 1:10, j = 1:10
    size = 1000*i
    push!(df, (size, "mnozenie_macierzy", multiplyMatrices(size)))
end
CSV.write(output, df)
# Out:
# "results.csv"

# %% [markdown]
# #### Wczytać dane z w/w pliku do jednego DataFrame w języku Julia.

# %%
data = CSV.read("results.csv", delim=",", DataFrame)
# Out:
# 200×3 DataFrame
#  Row │ size   type               time
#      │ Int64  String31           Float64
# ─────┼─────────────────────────────────────
#    1 │ 10000  iloczyn_skalarny   2.1166e-5
#    2 │ 10000  iloczyn_skalarny   9.042e-6
#    3 │ 10000  iloczyn_skalarny   7.709e-6
#    4 │ 10000  iloczyn_skalarny   7.709e-6
#    5 │ 10000  iloczyn_skalarny   7.708e-6
#    6 │ 10000  iloczyn_skalarny   7.708e-6
#    7 │ 10000  iloczyn_skalarny   7.75e-6
#    8 │ 10000  iloczyn_skalarny   7.667e-6
#    9 │ 10000  iloczyn_skalarny   7.709e-6
#   10 │ 10000  iloczyn_skalarny   7.708e-6
#   11 │ 20000  iloczyn_skalarny   1.5333e-5
#   ⋮  │   ⋮            ⋮              ⋮
#  191 │ 10000  mnozenie_macierzy  0.173523
#  192 │ 10000  mnozenie_macierzy  0.133795
#  193 │ 10000  mnozenie_macierzy  0.133084
#  194 │ 10000  mnozenie_macierzy  0.133417
#  195 │ 10000  mnozenie_macierzy  0.136452
#  196 │ 10000  mnozenie_macierzy  0.13706
#  197 │ 10000  mnozenie_macierzy  0.133326
#  198 │ 10000  mnozenie_macierzy  0.131721
#  199 │ 10000  mnozenie_macierzy  0.134993
#  200 │ 10000  mnozenie_macierzy  0.132841
#                            179 rows omitted

# %% [markdown]
# #### Korzystająć z mechanizmów DataFrame w języku Julia obliczyć średnią i odchylenie standardowe, w taki sposób, aby narysować wykresy średnich czasów obliczenia operacji w zależności od rozmiaru wektora. Dodać słupki błędów do obydwu wykresów uzyskanych z obliczenia odchylenia standardowego.

# %%
vectorData, matrixData = groupby(data, [:type])
# Out:
# GroupedDataFrame with 2 groups based on key: type
# First Group (100 rows): type = "iloczyn_skalarny"
#  Row │ size    type              time
#      │ Int64   String31          Float64
# ─────┼─────────────────────────────────────
#    1 │  10000  iloczyn_skalarny  2.1166e-5
#    2 │  10000  iloczyn_skalarny  9.042e-6
#    3 │  10000  iloczyn_skalarny  7.709e-6
#    4 │  10000  iloczyn_skalarny  7.709e-6
#   ⋮  │   ⋮            ⋮              ⋮
#   98 │ 100000  iloczyn_skalarny  7.6667e-5
#   99 │ 100000  iloczyn_skalarny  7.6667e-5
#  100 │ 100000  iloczyn_skalarny  7.6709e-5
#                             93 rows omitted
# ⋮
# Last Group (100 rows): type = "mnozenie_macierzy"
#  Row │ size   type               time
#      │ Int64  String31           Float64
# ─────┼───────────────────────────────────────
#    1 │  1000  mnozenie_macierzy  0.00103642
#    2 │  1000  mnozenie_macierzy  0.00072325
#    3 │  1000  mnozenie_macierzy  0.000835375
#   ⋮  │   ⋮            ⋮               ⋮
#   98 │ 10000  mnozenie_macierzy  0.131721
#   99 │ 10000  mnozenie_macierzy  0.134993
#  100 │ 10000  mnozenie_macierzy  0.132841
#                               94 rows omitted

# %%
vectorDescription = combine(groupby(vectorData, :size), "time" => 
(x -> (mean=mean(x), std=std(x))) => [:srednia, :odchylenie_std])
# Out:
# 10×3 DataFrame
#  Row │ size    srednia     odchylenie_std
#      │ Int64   Float64     Float64
# ─────┼────────────────────────────────────
#    1 │  10000  9.1876e-6       4.22964e-6
#    2 │  20000  1.5375e-5       3.92457e-8
#    3 │  30000  2.30585e-5      3.505e-8
#    4 │  40000  3.06792e-5      5.21447e-8
#    5 │  50000  3.83542e-5      4.93104e-8
#    6 │  60000  4.60126e-5      5.60103e-8
#    7 │  70000  5.37626e-5      2.05311e-7
#    8 │  80000  6.17666e-5      1.19526e-6
#    9 │  90000  6.90624e-5      4.91216e-8
#   10 │ 100000  7.67168e-5      4.29698e-8

# %%
matrixDescription = combine(groupby(matrixData, :size), "time" => 
(x -> (mean=mean(x), std=std(x))) => [:srednia, :odchylenie_std])
# Out:
# 10×3 DataFrame
#  Row │ size   srednia     odchylenie_std
#      │ Int64  Float64     Float64
# ─────┼───────────────────────────────────
#    1 │  1000  0.00141923     0.00181736
#    2 │  2000  0.00444912     0.00260191
#    3 │  3000  0.00831567     0.00100678
#    4 │  4000  0.0437439      0.043807
#    5 │  5000  0.0497356      0.00502946
#    6 │  6000  0.0513812      0.000751455
#    7 │  7000  0.0818931      0.0345748
#    8 │  8000  0.0887509      0.00348396
#    9 │  9000  0.10872        0.00174119
#   10 │ 10000  0.138021       0.0125827

# %%
plotVector = plot(vectorDescription.size, vectorDescription.srednia, yerr=vectorDescription.odchylenie_std,
                title="Iloczyn skalarny", label ="pomiary dla danego wektora", xlabel="dł. wektora", ylabel="pomiar")

# %%
plotMatrix = plot(matrixDescription.size, matrixDescription.srednia, yerr=matrixDescription.odchylenie_std, 
                title="Mnozenie macierzy", label = "pomiar dla macierzy", xlabel="rozmiar macierzy", ylabel="pomiar")

# %% [markdown]
# #### Proszę poukładac wykresy w tabelkę za pomocą opcji layouts: https://docs.juliaplots.org/latest/layouts/#Simple-Layouts-1.

# %%
plot(plotVector, plotMatrix, layout = 2)
